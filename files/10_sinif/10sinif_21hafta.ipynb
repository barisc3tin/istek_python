# %% [markdown]
# # 10. Sınıf – Bilişim Teknolojileri ve Yazılım
# ## 21. Hafta: Python Diziler (Listeler)
#
# ### TESLİM TALİMATI
# 1. File → **Save As...** ile dosya adını şu formata göre kaydedin:
#    **10A_AdSoyad_21Hafta.ipynb**
# 2. Tüm görevleri tamamlayın.
# 3. File → **Download → Notebook (.ipynb)**
# 4. LMS’e yükleyin / öğretmeninize gönderin.
#
# > Not: Bu materyal "To Do" görevleri içerir. Her görevde istenen çıktıyı üretmeniz beklenir.

# %% [markdown]
# ### Öğrenme hedefleri
# - Liste (dizi) tanımlar ve kullanır.
# - İndeks ile elemanlara erişir.
# - append/remove ile listeyi günceller.
# - Döngü ile liste üzerinde işlem yapar.
# - Liste kullanmanın avantajını açıklar.
#
# ### Kavramlar
# Liste, indeks, len(), append(), remove(), for döngüsü

# %%
# GÖREV 0 (Isınma)
# TODO: 'meyveler' adında 5 elemanlı bir liste oluşturun ve ekrana yazdırın.

meyveler = None  # TODO

print(meyveler)

# %%
# GÖREV 1 (İndeks)
# TODO: Listenin 0. elemanını ve son elemanını yazdırın.
# İpucu: son eleman için negatif indeks kullanabilirsiniz.

# TODO

# %%
# GÖREV 2 (Güncelleme)
# TODO:
# 1) Listeye "Çilek" ekleyin.
# 2) Listeden bir elemanı remove ile çıkarın.
# 3) Güncel listeyi yazdırın.

# TODO

# %%
# GÖREV 3 (Notlar - Ortalama)
# TODO:
# 1) 'notlar' adında 5 adet nottan oluşan bir liste oluşturun.
# 2) for döngüsü ile toplamı hesaplayın.
# 3) len(notlar) kullanarak ortalamayı bulun.
# 4) Ortalamayı ekrana yazdırın.

notlar = None  # TODO

# TODO: toplam hesapla
# TODO: ortalama hesapla ve yazdır

# %%
# GÖREV 4 (Filtreleme)
# TODO:
# 'notlar' listesindeki 50'nin altındaki notları 'dusuk_notlar' listesine aktarın.
# Sonra dusuk_notlar listesini yazdırın.

dusuk_notlar = []

# TODO
print("50 altı notlar:", dusuk_notlar)

# %% [markdown]
# ### Yansıma (Kısa cevap)
# 1) Liste kullanmasaydık notları nasıl saklardık?
# 2) Liste kullanmak kodun okunabilirliğini nasıl etkiledi?
# 3) Bu yapı gerçek hayatta hangi problemde işinize yarar?

# %%
# ÖĞRETMEN KONTROL ||| Öğretmen için
# Bu hücre öğrencinin doğru tipleri oluşturup oluşturmadığını kontrol eder.

assert isinstance(meyveler, list), "meyveler bir liste olmalı"
assert isinstance(dusuk_notlar, list), "dusuk_notlar bir liste olmalı"
assert isinstance(notlar, list), "notlar bir liste olmalı"

print("✅ Temel kontroller geçti.")
