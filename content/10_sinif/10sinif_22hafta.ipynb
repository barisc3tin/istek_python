# %% [markdown]
# # İSTEK OKULLARI 10. Sınıf | 22. Hafta
# ## Python: Listeler ve Hazır Fonksiyonlar (len, min, max, count, insert, sorted, zip)
#
# Talimatlar:
#
# Bu dosyayı "File > Save As" seçeneği ile AdSoyad_Sınıf_w22.ipynb ismi ile farklı kaydederek çalışmanıza başlayın.
# Eğer başka bir öğrenci tarafından gerçekleştirilen değişiklikler görüntülüyorsanız tarayıcınızı "gizli mod" veya "misafir modu" ile yeniden başlatın.
#
#
#
#
# **Ad Soyad:** ……………………………
# **Sınıf/Şube:** …………………………
# **Tarih:** …………………………………
#
# ---
#
# ### Bu derste ne yapacağız?
# - Liste (list) veri yapısını tekrar edeceğiz.
# - Hazır fonksiyonlarla listeler üzerinde işlem yapacağız: `len()`, `min()`, `max()`, `count()`, `insert()`, `sorted()`, `zip()`
# - Ülke verisi (yıllara göre nüfus) üzerinden analiz yapacağız.
#
# ### Çalışma ortamı notu
# - **JupyterLite kullanıyorsan:** Çalışmanın sonunda dosyayı indirip öğretmenin paylaştığı klasöre yüklemelisin.
# - **Colab kullanıyorsan:** `Dosya → Drive'a kopyasını kaydet` yapmalısın.

# %%
# ✅ HAZIR VERİ SETİ (dokunma)
# Her ülke için yıllara göre nüfus (milyon) değerleri (örnek veri)
ulkeler = ["Türkiye", "Almanya", "Japonya", "Brezilya", "Kanada"]

nufuslar = {
    "Türkiye":  [84.0, 84.7, 85.3, 85.9, 86.5],
    "Almanya":  [83.1, 83.0, 83.2, 83.3, 83.2],
    "Japonya":  [125.8, 125.1, 124.6, 124.1, 123.6],
    "Brezilya": [212.6, 214.0, 215.3, 216.4, 217.2],
    "Kanada":   [38.0, 38.3, 38.7, 39.1, 39.5]
}

yillar = [2020, 2021, 2022, 2023, 2024]

print("Ülkeler:", ulkeler)
print("Yıllar:", yillar)

# %% [markdown]
# ## Görev 1 — Ülke seç ve listeyi al (BTYAB3.3.SB2 / SB3)
#
# 1. Aşağıdaki değişkene listeden bir ülke yaz.
# 2. Seçtiğin ülkenin nüfus listesini `secili_liste` değişkenine aktar.
# 3. Ekrana seçtiğin ülkeyi ve listeyi yazdır.

# %%
# TODO 1: Ülke seç
secili_ulke = ""  # örn: "Türkiye"

# TODO 2: Seçilen ülkenin nüfus listesini al
secili_liste = None

# TODO 3: Yazdır
print("Seçilen ülke:", secili_ulke)
print("Nüfus listesi:", secili_liste)

# %% [markdown]
# ## Görev 2 — Liste uzunluğu ve min/max (BTYAB3.3.SB3)
#
# 1. `len()` ile listede kaç yıl verisi olduğunu bul.
# 2. `min()` ile en düşük nüfusu, `max()` ile en yüksek nüfusu bul.
# 3. Sonuçları açıklayıcı şekilde yazdır.

# %%
# TODO: len, min, max
liste_uzunlugu = None
en_kucuk = None
en_buyuk = None

print("Veri sayısı (yıl):", liste_uzunlugu)
print("En düşük nüfus:", en_kucuk)
print("En yüksek nüfus:", en_buyuk)

# %% [markdown]
# ## Görev 3 — sorted() ile sıralama (BTYAB3.3.SB3)
#
# Amaç: Nüfus değerlerine göre yılları sıralamak.
#
# İpucu:
# - `zip(yillar, secili_liste)` -> (yıl, nüfus) çiftleri oluşturur
# - `sorted(..., key=...)` ile sıralama yapılır
#
# İstenen:
# 1. `(yıl, nüfus)` çiftlerini oluştur.
# 2. Nüfusa göre küçükten büyüğe sırala.
# 3. Sonucu yazdır.

# %%
# TODO 1: yıl-nüfus çiftleri
yil_nufus = None

# TODO 2: nüfusa göre sırala (küçükten büyüğe)
sirali = None

print("Yıl-Nüfus çiftleri:", yil_nufus)
print("Nüfusa göre sıralı:", sirali)

# %% [markdown]
# ## Görev 4 — count() ve insert() (BTYAB3.3.SB3)
#
# Bu bölümde liste üzerinde düzenleme yapacağız.
#
# 1. `count()` ile listede belirli bir değerin kaç kez geçtiğini bul.
#    - Örn: `count(83.2)` gibi (seçtiğin ülkeye göre anlamlı bir değer seç)
# 2. `insert()` ile listeye yeni bir değer ekle:
#    - Örn: 2019 yılını ve nüfusunu başa eklemek için
#    - (Dikkat: `yillar` listesine de aynı konuma yıl eklemelisin)
#
# **Not:** Bu işlem, gerçek veri gibi düşünülerek yapılır. Mantığını doğru kurman önemli.

# %%
# TODO 1: count
aranan_deger = None
kac_kere = None
print("Aranan değer:", aranan_deger, "kaç kez geçiyor?", kac_kere)

# TODO 2: insert ile yeni veri ekleme
# Örnek: 2019 ve nüfus 83.0 gibi (sen seç)
yeni_yil = None
yeni_nufus = None

# yillar ve secili_liste aynı uzunlukta kalmalı!
# yillar.insert(0, yeni_yil)
# secili_liste.insert(0, yeni_nufus)

print("Güncellenmiş yıllar:", yillar)
print("Güncellenmiş nüfus listesi:", secili_liste)

# %% [markdown]
# ## Ana Görev — zip() ile ülke-nüfus özet tablosu (BTYAB3.3.SB3 / SB4)
#
# 1. Seçtiğin ülke için:
#    - `zip(yillar, secili_liste)` ile yıllara göre nüfus tablosu üret.
# 2. Çıktıyı şu formatta yazdır:
#    - `2020 → 84.0 milyon`
# 3. Son olarak 1 cümle yorum yaz:
#    - “Nüfus genel olarak artıyor/azalıyor çünkü ...”

# %%
# TODO: Tablo yazdır
# for yil, nufus in zip(yillar, secili_liste):
#     print(...)

yorum = ""  # TODO: 1 cümle yorum
print("Yorum:", yorum)

# %% [markdown]
# ## Exit Ticket (BTYAB3.3.SB4)
#
# 1) Listeler neden “tek tek değişken” kullanmaktan daha verimlidir? (1-2 cümle)
# 2) `sorted()` fonksiyonunu hangi problem için kullandın?
# 3) `zip()` sana ne avantaj sağladı?

# %%
# ✅ ÖĞRETMEN İÇİN KONTROL HÜCRESİ (dokunma)
kontrol = {
    "secili_ulke_dolu_mu": bool(secili_ulke),
    "secili_liste_liste_mi": isinstance(secili_liste, list),
    "len_hesaplandi_mi": liste_uzunlugu is not None,
    "minmax_hesaplandi_mi": (en_kucuk is not None and en_buyuk is not None),
    "sorted_yapildi_mi": sirali is not None,
    "exit_ticket_dolu_mu": all([bool(exit1), bool(exit2), bool(exit3)])
}
kontrol
